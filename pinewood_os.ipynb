# %%
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


data = pd.read_csv("pinewood_os_aq.csv") #33000 to 39000
data2 = pd.read_csv("pinewood_os.csv")

interval = 3600
start_time = data.iloc[69743,2]
end_time = data.iloc[74985 ,2]
cpm_hour = []
interval_difference = end_time - start_time
count = 0


start_time2 = data2.iloc[39000, 2]
end_time2 = data2.iloc[33775, 2]
interval_difference2 = end_time2 - start_time2
count2 = 0
cpm_hour2 = []


#########################################################################################################################

while count < int(interval_difference):
    selection_mask = (data['deviceTime_unix'] > (start_time + count)) & (data['deviceTime_unix'] < (start_time + count + interval))
    tempData = data[selection_mask]
    if (len(tempData) == 0):
        cpm_hour.append(None)
    else:
        cpm_hour.append(np.mean(tempData['PM25'])) 
    count += interval

while count2 < int(interval_difference2):
    selection_mask2 = (data2['deviceTime_unix'] > (start_time2 + count2)) & (data2['deviceTime_unix'] < (start_time2 + count2 + interval))
    tempData2 = data2[selection_mask2]
    if (len(tempData2) == 0):
        cpm_hour2.append(None)
    else:
        cpm_hour2.append(np.mean(tempData2['cpm']))       
    count2 += interval
        
counter = 0
while counter < len(cpm_hour):
    if (cpm_hour[counter] == None) or (cpm_hour2[counter] == None):
        del cpm_hour[counter]
        del cpm_hour2[counter]
    else:
        counter+=1
        
#########################################################################################################################################

time = list(data.iloc[69743:74985, 2])
newTime = list(range(len(cpm_hour)))
x = cpm_hour
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
y = cpm_hour2
ax.set_title('Air Quality vs. Geiger Counts')
plt.ylabel('Geiger Counts')
plt.xlabel('Air Quality PM25')
#plt.scatter(cpm_hour,cpm_hour2, marker='o')

coef = np.polyfit(x,y,1)
poly1d_fn = np.poly1d(coef) 
# poly1d_fn is now a function which takes in x and returns an estimate for y
m,b = np.polyfit(x, y, 1)
plt.plot(x,y, 'co', x, poly1d_fn(x),'r')
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print("p-value: ", round(p_value,4), " slope: ", round(slope,10), " y intercept: ",  round(intercept, 3),"\n", "r squared: ", round((r_value)**2, 4), " standard error: ", round(std_err, 10))
# Out:
# p-value:  0.1209  slope:  0.0002353222  y intercept:  2.188
#  r squared:  0.0057  standard error:  0.000151424

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv("pinewood_os_d3s.csv",nrows = 90000,usecols = ["deviceTime_utc", "cpm", "deviceTime_unix"])
#82221    2018-11-28 08:16:54+00:00
#76902    2018-11-08 03:02:02+00:00
print(data.iloc[82220:82230,0])
# Out:
# 82220    2018-11-28 08:11:59+00:00
# 82221    2018-11-28 08:16:54+00:00
# 82222    2018-11-28 08:21:54+00:00
# 82223    2018-11-28 08:26:54+00:00
# 82224    2018-11-28 08:26:59+00:00
# 82225    2018-11-28 08:31:54+00:00
# 82226    2018-11-28 08:36:55+00:00
# 82227    2018-11-28 08:41:55+00:00
# 82228    2018-11-28 08:46:55+00:00
# 82229    2018-11-28 08:51:55+00:00
# Name: deviceTime_utc, dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv("pinewood_os_aq.csv") #69743 to 74985 
#2018-11-08 03:01:09+00:00
#2018-11-28 08:16:20+00:00
print(data.iloc[69743,2])
print(data.iloc[74985, 2])
# Out:
# 1541646069
# 1543392980

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv("pinewood_os.csv")
#39000    2018-11-08 03:00:44+00:00
#33775    2018-11-28 08:15:56+00:00

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv("pinewood_os_aq.csv") #33000 to 39000
data2 = pd.read_csv("pinewood_os_d3s.csv")

interval = 3600
start_time = data.iloc[69743,2]
end_time = data.iloc[74985 ,2]
cpm_hour = []
interval_difference = end_time - start_time
count = 0


start_time2 = data2.iloc[76902, 2]
end_time2 = data2.iloc[82221, 2]
interval_difference2 = end_time2 - start_time2
count2 = 0
cpm_hour2 = []


#########################################################################################################################

while count < int(interval_difference):
    selection_mask = (data['deviceTime_unix'] > (start_time + count)) & (data['deviceTime_unix'] < (start_time + count + interval))
    tempData = data[selection_mask]
    if (len(tempData) == 0):
        cpm_hour.append(None)
    else:
        cpm_hour.append(np.mean(tempData['PM25'])) 
    count += interval

while count2 < int(interval_difference2):
    selection_mask2 = (data2['deviceTime_unix'] > (start_time2 + count2)) & (data2['deviceTime_unix'] < (start_time2 + count2 + interval))
    tempData2 = data2[selection_mask2]
    if (len(tempData2) == 0):
        cpm_hour2.append(None)
    else:
        cpm_hour2.append(np.mean(tempData2['cpm']))       
    count2 += interval
        
print(interval_difference)
print(interval_difference2)

counter = 0
while counter < len(cpm_hour):
    if (cpm_hour[counter] == None) or (cpm_hour2[counter] == None):
        del cpm_hour[counter]
        del cpm_hour2[counter]
    else:
        counter+=1
        
#########################################################################################################################################

time = list(data.iloc[33000:39000, 2])
newTime = list(range(len(cpm_hour)))
x = cpm_hour
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
y = cpm_hour2
ax.set_title('Air Quality vs. Cesium Iodide Counts')
plt.ylabel('Cesium Iodide Counts')
plt.xlabel('Air Quality PM25')
#plt.scatter(cpm_hour,cpm_hour2, marker='o')

coef = np.polyfit(x,y,1)
poly1d_fn = np.poly1d(coef) 
# poly1d_fn is now a function which takes in x and returns an estimate for y
m,b = np.polyfit(x, y, 1)
plt.plot(x,y, 'co', x, poly1d_fn(x),'r')

slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print("p-value: ", round(p_value,4), " slope: ", round(slope,10), " y intercept: ",  round(intercept, 3),"\n", "r squared: ", round((r_value)**2, 4), " standard error: ", round(std_err, 10))
# Out:
# 1746911
# 1746892
# p-value:  0.0  slope:  0.7649815099  y intercept:  1252.866
#  r squared:  0.2884  standard error:  0.0582824056

# %%
#Fire season vs. Non Fire Season
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv("pinewood_os_d3s.csv")
#print(data)
#23191    2018-05-02 00:03:22+00:00
interval = 3600
start_time = data.iloc[0,2]
end_time = data.iloc[5799,2]
cpm_hour = []
interval_difference = end_time - start_time
count = 0

start_time2 = data.iloc[76902, 2]
end_time2 = data.iloc[82221, 2]
interval_difference2 = end_time2 - start_time2
count2 = 0
cpm_hour2 = []

while count < int(interval_difference):
    selection_mask = (data['deviceTime_unix'] > (start_time + count)) & (data['deviceTime_unix'] < (start_time + count + interval))
    tempData = data[selection_mask]
    if (len(tempData) == 0):
        cpm_hour.append(None)
    else:
        cpm_hour.append(np.mean(tempData['cpm'])) 
    count += interval
    
while count2 < int(interval_difference2):
    selection_mask2 = (data['deviceTime_unix'] > (start_time2 + count2)) & (data['deviceTime_unix'] < (start_time2 + count2 + interval))
    tempData2 = data[selection_mask2]
    if (len(tempData2) == 0):
        cpm_hour2.append(None)
    else:
        cpm_hour2.append(np.mean(tempData2['cpm']))       
    count2 += interval
    
counter = 0
while counter < len(cpm_hour):
    if (cpm_hour[counter] == None) or (cpm_hour[counter] > 2000) or (cpm_hour2[counter] == None) :
        del cpm_hour[counter]
        del cpm_hour2[counter]
    else:
        counter+=1

x = list(range(len(cpm_hour)))
x2 = list(range(len(cpm_hour2)))
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
y = cpm_hour
y2 = cpm_hour2
ax.plot(x,y, "-b", label = "Non-Fire Season")
ax.plot(x2,y2, "-r", label = "Fire Season")
ax.legend(loc="upper left")
ax.set_xlabel("Time")
ax.set_ylabel("Cesium Iodide Counts")
ax.set_title('Pinewood Outside Cesium Iodide Count')
ax.set_ylim(600, 2000)
# Out:
# (600.0, 2000.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#20926    2018-05-02 00:03:39+00:00
data = pd.read_csv("pinewood_os_aq.csv")

interval = 3600
start_time = data.iloc[0,2]
end_time = data.iloc[5686,2]
cpm_hour = []
interval_difference = end_time - start_time
count = 0

start_time2 = data.iloc[69743,2]
end_time2 = data.iloc[74980 ,2]
cpm_hour2 = []
interval_difference2 = end_time2 - start_time2
count = 0
print(interval_difference)
print(interval_difference2)
while count < int(interval_difference):
    selection_mask = (data['deviceTime_unix'] > (start_time + count)) & (data['deviceTime_unix'] < (start_time + count + interval))
    tempData = data[selection_mask]
    if (len(tempData) == 0):
        cpm_hour.append(None)
    else:
        cpm_hour.append(np.mean(tempData['PM25'])) 
    count += interval
    
count2 = 0
while count2 < int(interval_difference2):
    selection_mask2 = (data['deviceTime_unix'] > (start_time2 + count2)) & (data['deviceTime_unix'] < (start_time2 + count2 + interval))
    tempData2 = data[selection_mask2]
    if (len(tempData2) == 0):
        cpm_hour2.append(None)
    else:
        cpm_hour2.append(np.mean(tempData2['PM25']))       
    count2 += interval
    
print(len(cpm_hour))
print(len(cpm_hour2))
counter = 0
while counter < len(cpm_hour):
    if (cpm_hour[counter] == None) or (cpm_hour2[counter] == None) :
        del cpm_hour[counter]
        del cpm_hour2[counter]
    else:
        counter+=1

x = list(range(len(cpm_hour)))
x2 = list(range(len(cpm_hour2)))
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
y = cpm_hour
y2 = cpm_hour2
ax.plot(x,y, "-b", label = "Non-Fire Season")
ax.plot(x2,y2, "-r", label = "Fire Season")
ax.legend(loc="upper left")
ax.set_xlabel("Time")
ax.set_ylabel("AQI")
ax.set_title('Pinewood Outside Air Quality')
ax.set_ylim(0,300)
# Out:
# 1682637
# 1745711
# 468
# 485
# (0.0, 300.0)

# %%
#1519203600
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data = pd.read_csv("pinewood_os_aq.csv")

        
#2018-02-21 08:46:10+00:00 5686
print(data.iloc[5686,2] - data.iloc[0,2])
print(data.iloc[74950,2] - data.iloc[69743 ,2])
# Out:
# 1682637
# 1738516

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data = pd.read_csv("pinewood_os_d3s.csv")

for i in range(len(data)):
    if (data.iloc[i,2] < (1519203600+1000)) and (data.iloc[i,2] > (1519203600 - 1000)):
        print(data.iloc[i,0],i)
        
#2018-02-21 08:46:40+00:00 5799
print(data.iloc[76902, 2] - data.iloc[82221, 2])
print(data.iloc[5799,2] - data.iloc[0,2])
# Out:
# 2018-02-21 08:46:40+00:00 5799
# 2018-02-21 08:51:40+00:00 5800
# 2018-02-21 08:56:41+00:00 5801
# 2018-02-21 09:01:41+00:00 5802
# 2018-02-21 09:06:41+00:00 5803
# 2018-02-21 09:11:41+00:00 5804
# -1746892
# 1682690
